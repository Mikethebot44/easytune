# %% [markdown]
# # EasyTune Fashion Similarity (Image)
#
# This notebook demonstrates fine-tuning `facebook/dinov2-base` for image similarity using EasyTune.

# %%
from easytune import FineTuner

tuner = FineTuner(model="facebook/dinov2-base", task="image-similarity")
# Expect dataset layout: root/class_x/*.jpg
# tuner.add_from_folder("./fashion_images")
# tuner.train(epochs=3, batch_size=16, learning_rate=1e-5)
# tuner.save("fine_tuned_dinov2")
